# %%
using CSV, DataFrames
using Gurobi, JuMP
using Plots

# %%
function process_job_shop_data(filename::String)
    df = CSV.File(filename) |> DataFrame

    # Initialize dictionaries
    LL, GG, MG, nk, Nk, TIK, JobMachine, JobMachine1, JobMachine2, JO = Dict(), Dict(), Dict(), Dict(), Dict(), Dict(), Dict(), Dict(), Dict(), []
    
    # Parse the DataFrame
    for row in eachrow(df)
        job_id = row["Job ID"]
        group_id = row["Group ID"]
        operation_id = row["Operation ID"]
        machine_ids = split(row["Machine ID"], " or ")
        times = split(row["Time (s)"], " or ")
    
        # Populate LL, GG, JO
        push!(get!(LL, job_id, []), operation_id)
        push!(get!(GG, job_id, []), group_id)
        push!(JO, (job_id, operation_id))
    
        # Populate MG, nk
        for mid in machine_ids
            m = parse(Int, mid)
            push!(get!(MG, (job_id, group_id), []), m)
            nk[m] = get(nk, m, 0) + 1
        end
    
        # Populate Nk
        for (i, mid) in enumerate(machine_ids)
            m = parse(Int, mid)
            push!(get!(Nk, m, []), (job_id, operation_id))
            # Populate TIK
            TIK[(job_id, operation_id, m)] = parse(Int, times[i])
        end
    
        # Populate JobMachine, JobMachine1, JobMachine2
        push!(get!(JobMachine, job_id, []), machine_ids...)
        if length(machine_ids) > 1
            JobMachine1[job_id] = [parse(Int, machine_ids[1])]
            JobMachine2[job_id] = [parse(Int, machine_ids[2])]
        else
            JobMachine1[job_id] = [parse(Int, machine_ids[1])]
        end
    end
    
    # Remove duplicates and sort the lists in the dictionaries
    LL = Dict(job_id => sort(unique(ops)) for (job_id, ops) in LL)
    GG = Dict(job_id => sort(unique(groups)) for (job_id, groups) in GG)
    MG = Dict(k => unique(v) for (k, v) in MG)
    Nk = Dict(k => unique(v) for (k, v) in Nk)
    JobMachine = Dict(k => unique(v) for (k, v) in JobMachine)
    JobMachine1 = Dict(k => unique(v) for (k, v) in JobMachine1)
    JobMachine2 = Dict(k => unique(v) for (k, v) in JobMachine2)
    JO = unique(JO)
    
    # Calculate GCJ - group count for each job
    GCJ = Dict(job_id => length(groups) for (job_id, groups) in GG)
    
    # Determine the number of jobs (II) and the number of machines (MM)
    II = maximum(df[!, "Job ID"])
    MM = parse(Int, maximum(reduce(vcat, values(JobMachine))));
    
    # Initialize the dictionaries
    Nk = Dict()
    TIK = Dict()
    JobMachine = Dict()
    JobMachine1 = Dict()
    JobMachine2 = Dict((i, []) for i in 1:II)
    
    # Process the DataFrame
    for row in eachrow(df)
        job_id = row["Job ID"]
        operation_id = row["Operation ID"]
        machine_id_str = row["Machine ID"]
        time_str = row["Time (s)"]
    
        # Split the machine IDs and times if they contain "or"
        machine_ids = split(machine_id_str, " or ")
        times = split(time_str, " or ")
    
        # Assume the first machine and time are always directly assigned (no "or")
        primary_machine = parse(Int, machine_ids[1])
        primary_time = parse(Int, times[1])
    
        # Populate the TIK dictionary for the primary machine
        TIK[(job_id, primary_machine)] = primary_time
    
        # Populate the JobMachine and JobMachine1 dictionaries
        push!(get!(JobMachine, job_id, []), primary_machine)
        if length(machine_ids) == 1
            push!(get!(JobMachine1, job_id, []), primary_machine)
        end
    
        # Handle additional machines and times if present
        if length(machine_ids) > 1
            for i in 2:length(machine_ids)
                secondary_machine = parse(Int, machine_ids[i])
                secondary_time = parse(Int, times[i])
                
                # Populate the TIK dictionary for the secondary machine
                TIK[(job_id, secondary_machine)] = secondary_time
            end
            for i in 1:length(machine_ids)
                secondary_machine = parse(Int, machine_ids[i])
                # Populate the JobMachine and JobMachine2 dictionaries
                idx = findfirst(==(secondary_machine), JobMachine1)
                if idx !== nothing
                    deleteat!(JobMachine1, idx)
                end
                push!(get!(JobMachine, job_id, []), secondary_machine)
                push!(get!(JobMachine2, job_id, []), secondary_machine)
            end
        end
    
        # Populate the Nk dictionary
        for m_id in machine_ids
            machine_id = parse(Int, m_id)
            push!(get!(Nk, machine_id, []), job_id)
        end
    end
    
    # Remove duplicates from the lists in the dictionaries
    JobMachine = Dict(job_id => unique(machines) for (job_id, machines) in JobMachine)
    JobMachine1 = Dict(job_id => unique(machines) for (job_id, machines) in JobMachine1)
    JobMachine2 = Dict(job_id => unique(machines) for (job_id, machines) in JobMachine2)
    Nk = Dict(machine_id => unique(jobs) for (machine_id, jobs) in Nk);

    return LL, GG, MG, nk, Nk, TIK, JobMachine, JobMachine1, JobMachine2, JO, GCJ, II, MM
end;

# %%
function build_optimization_model(filename::String, M=2000, time_limit=10.0)
    LL, GG, MG, nk, Nk, TIK, JobMachine, JobMachine1, JobMachine2, JO, GCJ, II, MM = process_job_shop_data(filename)
    
    model = Model(Gurobi.Optimizer)
    
    # Decision Variables - Sparse definition using a dictionary
    validx = [ (i, j, k) for i in 1:II for k in JobMachine[i] for j in 1:nk[k] ]
    @variable(model, x[validx], Bin)
    @variable(model, h[[ (j, k) for k in 1:MM for j in 1:nk[k] ]] >= 0, Int)
    @variable(model, s[[ (j, k) for k in 1:MM for j in 1:nk[k] ]] >= 0, Int)
    @variable(model, s0[ k in 1:MM ] >= 0, Int)
    @variable(model, TX[[ (j, k) for k in 1:MM for j in 1:nk[k] ]] >= 0, Int)
    valid_deltas = []
    for (group, machines) in MG
        for a in 1:length(machines)
            for b in (a+1):length(machines)  # Ensure b > a to get unique pairs without repetition
                for jj in 1:nk[machines[a]], jjj in 1:nk[machines[b]]
                    push!( valid_deltas, (group[1], group[2], machines[a], machines[b], jj, jjj) )
                end
            end
        end
    end
    @variable(model, delta[ valid_deltas ], Bin);
    @variable(model, h_star >= 0, Int);
    
    # Objective: Minimize the maximum completion time
    @objective(model, Min, h_star);
    
    # Constraint Set 1: Each job is processed a specific number of times
    for i in 1:II
        for k in JobMachine1[i]
            @constraint(model, sum(x[(i, j, k)] for j in 1:nk[k]) == 1)
        if length(JobMachine2[i]) > 0
            k1 = JobMachine2[i][1]
            k2 = JobMachine2[i][2]
            @constraint(model, sum(x[(i, j, k1)] for j in 1:nk[k1]) + sum(x[(i, j, k2)] for j in 1:nk[k2]) == 1)
            end
        end
    end
    
    # Constraint Set 2: At most one operation at each order position on each machine
    for k in 1:MM 
        for j in 1:nk[k]
            @constraint(model, sum(x[(i, j, k)] for i in Nk[k]) <= 1)
        end
    end
    
    # Constraint Set 3: Define the processing time for each order position on each machine
    for k in 1:MM
        for j in 1:nk[k]
            @constraint(model, TX[(j, k)] == sum( get(TIK, (i, k), 0) * x[(i, j, k)] for i in Nk[k] ))
        end
    end
    for k in 1:MM
        @constraint(model, h[(1, k)] == s0[k])
    end
    for k in 1:MM
        for j in 2:nk[k]
            @constraint(model, h[(j, k)] == sum( TX[(q, k)] for q in 1:j-1 ) + sum( s[(q, k)] for q in 1:j-1 ) + s0[k])
        end
    end
    
    # Constraint Set 4: Precedence constraints
    M = 2000
    for i in 1:II
        for g1 in 2:GCJ[i]
            g = g1 - 1
            # g and g1 are group id of job i: g & g+1
            for a in MG[(i, g)]
                for b in MG[(i, g1)]
                    # println("job ", i, " machine a ", a, " machine b ", b)
                    for jj in 1:nk[a]
                        for jjj in 1:nk[b]
                            @constraint(
                                model, 
                                h[(jj, a)] + get(TIK, (i, a), 0) * x[(i, jj, a)] <= h[(jjj, b)] + M * (1 - x[(i, jj, a)]) + M * (1 - x[(i, jjj, b)])
                            )
                        end
                    end
                end
            end
        end
    end
    
    # # Constraint Set 5: No overlap within the same machine group
    # for (group, machines) in MG
    #     for a in 1:length(machines)
    #         for b in (a+1):length(machines)  # Ensure b > a to get unique pairs without repetition
    #             for jj in 1:nk[machines[a]]
    #                 for jjj in 1:nk[machines[b]]
    #                     i = group[1]
    #                     ma = machines[a]
    #                     mb = machines[b]
    #                     @constraint(
    #                         model, 
    #                         h[(jj, ma)] + get(TIK, (i, ma), 0) * x[(i, jj, ma)] <= h[(jjj, mb)] + M * (1 - x[(i, jj, ma)]) + M * (1 - x[(i, jjj, mb)]) 
    #                         + 3 * M * delta[(i, group[2], ma, mb, jj, jjj)]
    #                     )
    #                     @constraint(
    #                         model, 
    #                         h[(jjj, mb)] + get(TIK, (i, mb), 0) * x[(i, jjj, mb)] <= h[(jj, ma)] + M * (1 - x[(i, jj, ma)]) + M * (1 - x[(i, jjj, mb)]) 
    #                         + 3 * M * (1 - delta[(i, group[2], ma, mb, jj, jjj)])
    #                     )
    #                 end
    #             end
    #         end
    #     end
    # end
    
    # Constraint Set 6: h_star is greater than or equal to the end time of the last operation on each machine
    for k in 1:MM
        @constraint(model, h_star >= h[(nk[k], k)] + TX[(nk[k], k)])
    end
    
    # Constraint Set 7: order pos
    for k in 1:MM 
        for j in 2:nk[k]
            jprev = j - 1
            @constraint(model, sum(x[(i, jprev, k)] for i in Nk[k]) >= sum(x[(i, j, k)] for i in Nk[k]))
        end
    end
    
    # Optimize 
    set_time_limit_sec(model, time_limit) # run at most 10s
    optimize!(model);

    # result
    x_result = Dict()
    for idx in [ (i, j, k) for i in 1:II for k in JobMachine[i] for j in 1:nk[k] ]
        x_result[idx] = value.(x[idx])
    end
    h_result = Dict()
    for idx in [ (j, k) for k in 1:MM for j in 1:nk[k] ]
        h_result[idx] = value.(h[idx])
    end
    s_result = Dict()
    for idx in [ (j, k) for k in 1:MM for j in 1:nk[k] ]
        s_result[idx] = value.(s[idx])
    end
    s0_result = Dict()
    for idx in 1:MM
        s0_result[idx] = value.(s0[idx])
    end
    TX_result = Dict()
    for idx in [ (j, k) for k in 1:MM for j in 1:nk[k] ]
        TX_result[idx] = value.(TX[idx])
    end

    return model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result
end;

# %%
# Function to plot Gantt chart with job legends
function plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, num_jobs)
    end_times = Dict()
    for (j, k) in keys(TX_result)
        end_times[(j, k)] = h_result[(j, k)] + TX_result[(j, k)]
    end
    
    gantt_chart = plot(title="Job Schedule Gantt Chart by Machine", legend=:outertopright)

    # Generate a color for each job
    job_colors = distinguishable_colors(num_jobs)

    # Dictionary to keep track of which jobs have been plotted (to avoid duplicate legend entries)
    plotted_jobs = Dict()
    
    # Plot each task
    for k in 1:MM
        machine_schedule = []
        # Gather the tasks for this machine
        for i in 1:II
            for j in 1:nk[k]
                if get(x_result, (i, j, k), 0) > 0.1
                    push!(machine_schedule, (h_result[(j, k)], h_result[(j, k)] + TX_result[(j, k)], i))
                    break
                end
            end
        end
        for (start, finish, job_id) in machine_schedule
            color = job_colors[job_id]
            label = haskey(plotted_jobs, job_id) ? "" : "Job $job_id"  # Only label the first task of each job
            plotted_jobs[job_id] = true
            # plot!([start, finish], [k, k], bar=(150, color), label=label)
            shape = Shape([start, start, finish, finish], 
                      [k - 0.4, k + 0.4, k + 0.4, k - 0.4])
            plot!(shape, color=color, label=label)
        end
    end

    xlabel!("Time")
    ylabel!("Machine")
    return gantt_chart
end;

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 4.csv", 2000, 4)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 4
# Set parameter TimeLimit to value 4
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 298 rows, 227 columns and 1269 nonzeros
# Model fingerprint: 0x02a6a8b4
# Variable types: 0 continuous, 227 integer (159 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 75 rows and 138 columns
# Presolve time: 0.00s
# Presolved: 223 rows, 89 columns, 882 nonzeros
# Variable types: 0 continuous, 89 integer (67 binary)
#
# Root relaxation: objective 1.800000e+02, 65 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  180.00000    0   21          -  180.00000      -     -    0s
# H    0     0                     280.0000000  180.00000  35.7%     -    0s
# H    0     0                     250.0000000  180.00000  28.0%     -    0s
# H    0     0                     220.0000000  180.00000  18.2%     -    0s
#      0     0  210.00000    0   28  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   16  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   15  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   18  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   15  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   18  220.00000  210.00000  4.55%     -    0s
#      0     0  210.00000    0   15  220.00000  210.00000  4.55%     -    0s
#      0     0  220.00000    0    5  220.00000  220.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 5
#   Implied bound: 2
#   Clique: 2
#   MIR: 7
#   RLT: 5
#
# Explored 1 nodes (502 simplex iterations) in 0.03 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 220 250 280
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.200000000000e+02, best bound 2.200000000000e+02, gap 0.0000%
#
# User-callback calls 628, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 6.csv", 2000, 6)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 6
# Set parameter TimeLimit to value 6
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 668 rows, 434 columns and 3029 nonzeros
# Model fingerprint: 0x917c2598
# Variable types: 0 continuous, 434 integer (345 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 102 rows and 255 columns
# Presolve time: 0.00s
# Presolved: 566 rows, 179 columns, 2384 nonzeros
# Variable types: 0 continuous, 179 integer (137 binary)
#
# Root relaxation: objective 2.400000e+02, 134 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  240.00000    0   21          -  240.00000      -     -    0s
# H    0     0                     390.0000000  240.00000  38.5%     -    0s
#      0     0  240.00000    0   39  390.00000  240.00000  38.5%     -    0s
# H    0     0                     365.0000000  240.00000  34.2%     -    0s
#      0     0  240.00000    0   21  365.00000  240.00000  34.2%     -    0s
#      0     0  240.00000    0   24  365.00000  240.00000  34.2%     -    0s
#      0     0  240.00000    0   24  365.00000  240.00000  34.2%     -    0s
# H    0     0                     310.0000000  240.00000  22.6%     -    0s
#      0     0  240.00000    0   41  310.00000  240.00000  22.6%     -    0s
# H    0     0                     305.0000000  240.00000  21.3%     -    0s
#      0     0  240.00000    0   15  305.00000  240.00000  21.3%     -    0s
#      0     0  240.00000    0   15  305.00000  240.00000  21.3%     -    0s
#      0     0  240.00000    0   16  305.00000  240.00000  21.3%     -    0s
#      0     0  240.00000    0   29  305.00000  240.00000  21.3%     -    0s
# H    0     0                     295.0000000  256.36364  13.1%     -    0s
#      0     0  256.36364    0   17  295.00000  256.36364  13.1%     -    0s
#      0     0  256.36364    0   24  295.00000  256.36364  13.1%     -    0s
# H    0     0                     290.0000000  256.66667  11.5%     -    0s
# H    0     0                     280.0000000  256.66667  8.33%     -    0s
#      0     0  256.66667    0   29  280.00000  256.66667  8.33%     -    0s
#      0     0  257.09100    0   26  280.00000  257.09100  8.18%     -    0s
#      0     2  257.09100    0   13  280.00000  257.09100  8.18%     -    0s
#
# Cutting planes:
#   Learned: 4
#   Cover: 39
#   Implied bound: 11
#   Clique: 7
#   MIR: 11
#   Inf proof: 15
#   RLT: 5
#   Relax-and-lift: 1
#
# Explored 2708 nodes (15039 simplex iterations) in 0.29 seconds (0.32 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 280 290 295 ... 390
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.800000000000e+02, best bound 2.800000000000e+02, gap 0.0000%
#
# User-callback calls 6057, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 8.csv", 2000, 8)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 8
# Set parameter TimeLimit to value 8
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1689 rows, 984 columns and 7734 nonzeros
# Model fingerprint: 0x69769096
# Variable types: 0 continuous, 984 integer (862 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 203 rows and 653 columns
# Presolve time: 0.01s
# Presolved: 1486 rows, 331 columns, 6469 nonzeros
# Variable types: 0 continuous, 331 integer (264 binary)
#
# Root relaxation: objective 3.600000e+02, 239 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  360.00000    0   14          -  360.00000      -     -    0s
# H    0     0                     645.0000000  360.00000  44.2%     -    0s
# H    0     0                     585.0000000  360.00000  38.5%     -    0s
#      0     0  360.00000    0   23  585.00000  360.00000  38.5%     -    0s
# H    0     0                     550.0000000  360.00000  34.5%     -    0s
# H    0     0                     490.0000000  360.00000  26.5%     -    0s
#      0     0  360.00000    0    8  490.00000  360.00000  26.5%     -    0s
# H    0     0                     460.0000000  360.00000  21.7%     -    0s
# H    0     0                     440.0000000  360.00000  18.2%     -    0s
# H    0     0                     420.0000000  360.00000  14.3%     -    0s
# H    0     0                     405.0000000  360.00000  11.1%     -    0s
#      0     0  360.00000    0   11  405.00000  360.00000  11.1%     -    0s
# H    0     0                     400.0000000  360.00000  10.0%     -    0s
#      0     0  360.00000    0    7  400.00000  360.00000  10.0%     -    0s
#      0     0  360.00000    0   22  400.00000  360.00000  10.0%     -    0s
#      0     0  360.00000    0   10  400.00000  360.00000  10.0%     -    0s
#      0     0  360.00000    0   10  400.00000  360.00000  10.0%     -    0s
#      0     0  360.00000    0    8  400.00000  360.00000  10.0%     -    0s
#      0     0  360.00000    0   21  400.00000  360.00000  10.0%     -    0s
#      0     0  363.33333    0   52  400.00000  363.33333  9.17%     -    0s
#      0     0  366.00000    0   40  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   40  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   41  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   41  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   30  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   26  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   31  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   31  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   31  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   29  400.00000  366.00000  8.50%     -    0s
#      0     0  366.00000    0   28  400.00000  366.00000  8.50%     -    0s
#      0     2  366.00000    0   28  400.00000  366.00000  8.50%     -    0s
#
# Explored 9550 nodes (60904 simplex iterations) in 1.14 seconds (1.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 400 405 420 ... 645
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+02, best bound 4.000000000000e+02, gap 0.0000%
#
# User-callback calls 20031, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 10.csv", 2000, 10)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 10
# Set parameter TimeLimit to value 10
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2244 rows, 1340 columns and 10437 nonzeros
# Model fingerprint: 0xd5c12425
# Variable types: 0 continuous, 1340 integer (1200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 65 rows and 895 columns
# Presolve time: 0.01s
# Presolved: 2179 rows, 445 columns, 9779 nonzeros
# Variable types: 0 continuous, 445 integer (360 binary)
#
# Root relaxation: objective 3.600000e+02, 277 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  360.00000    0   33          -  360.00000      -     -    0s
#      0     0  360.00000    0   69          -  360.00000      -     -    0s
#      0     0  360.00000    0   68          -  360.00000      -     -    0s
#      0     0  360.00000    0   31          -  360.00000      -     -    0s
# H    0     0                     630.0000000  360.00000  42.9%     -    0s
# H    0     0                     570.0000000  360.00000  36.8%     -    0s
#      0     0  360.00000    0   27  570.00000  360.00000  36.8%     -    0s
#      0     0  360.00000    0   30  570.00000  360.00000  36.8%     -    0s
# H    0     0                     560.0000000  360.00000  35.7%     -    0s
# H    0     0                     520.0000000  360.00000  30.8%     -    0s
#      0     0  360.00000    0   16  520.00000  360.00000  30.8%     -    0s
# H    0     0                     515.0000000  360.00000  30.1%     -    0s
# H    0     0                     485.0000000  360.00000  25.8%     -    0s
#      0     0  360.00000    0   20  485.00000  360.00000  25.8%     -    0s
#      0     0  360.00000    0   17  485.00000  360.00000  25.8%     -    0s
#      0     0  360.00000    0   22  485.00000  360.00000  25.8%     -    0s
#      0     0  360.00000    0   22  485.00000  360.00000  25.8%     -    0s
# H    0     0                     430.0000000  360.00000  16.3%     -    0s
#      0     0  360.00000    0   15  430.00000  360.00000  16.3%     -    0s
#      0     0  360.00000    0   15  430.00000  360.00000  16.3%     -    0s
# H    0     0                     405.0000000  360.00000  11.1%     -    0s
#      0     2  360.00000    0   12  405.00000  360.00000  11.1%     -    0s
# H   89    75                     400.0000000  360.00000  10.0%  17.8    0s
#
# Cutting planes:
#   Gomory: 23
#   Lift-and-project: 4
#   Cover: 15
#   Projected implied bound: 2
#   Clique: 4
#   MIR: 1
#   StrongCG: 8
#   Flow cover: 14
#   Zero half: 4
#   RLT: 9
#
# Explored 1881 nodes (28247 simplex iterations) in 1.35 seconds (2.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 400 405 430 ... 630
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+02, best bound 4.000000000000e+02, gap 0.0000%
#
# User-callback calls 4590, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 12.csv", 2000, 12)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 12
# Set parameter TimeLimit to value 12
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4348 rows, 2414 columns and 19905 nonzeros
# Model fingerprint: 0x5d0de114
# Variable types: 0 continuous, 2414 integer (2241 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 73 rows and 1750 columns
# Presolve time: 0.01s
# Presolved: 4275 rows, 664 columns, 18898 nonzeros
# Variable types: 0 continuous, 664 integer (555 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 4.800000e+02, 453 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  480.00000    0   11          -  480.00000      -     -    0s
#      0     0  480.00000    0   60          -  480.00000      -     -    0s
#      0     0  480.00000    0   12          -  480.00000      -     -    0s
# H    0     0                     580.0000000  480.00000  17.2%     -    0s
#      0     0  480.00000    0   16  580.00000  480.00000  17.2%     -    0s
# H    0     0                     550.0000000  480.00000  12.7%     -    0s
#      0     0  480.00000    0   17  550.00000  480.00000  12.7%     -    0s
#      0     0  480.00000    0   26  550.00000  480.00000  12.7%     -    0s
#      0     0  480.00000    0   18  550.00000  480.00000  12.7%     -    0s
# H    0     0                     540.0000000  480.00000  11.1%     -    0s
#      0     0  480.00000    0   11  540.00000  480.00000  11.1%     -    0s
#      0     0  480.00000    0   14  540.00000  480.00000  11.1%     -    0s
#      0     0  480.00000    0    4  540.00000  480.00000  11.1%     -    0s
#      0     0  480.00000    0   17  540.00000  480.00000  11.1%     -    0s
# H    0     0                     520.0000000  480.00000  7.69%     -    0s
#      0     0  480.00000    0   15  520.00000  480.00000  7.69%     -    0s
#      0     0  480.00000    0   15  520.00000  480.00000  7.69%     -    0s
#      0     2  480.00000    0   11  520.00000  480.00000  7.69%     -    0s
#
# Explored 3841 nodes (40115 simplex iterations) in 1.91 seconds (4.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 520 540 550 580
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.200000000000e+02, best bound 5.200000000000e+02, gap 0.0000%
#
# User-callback calls 8797, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 14.csv", 2000, 14)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 14
# Set parameter TimeLimit to value 14
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 6556 rows, 3661 columns and 29837 nonzeros
# Model fingerprint: 0x2489896b
# Variable types: 0 continuous, 3661 integer (3461 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 75 rows and 2785 columns
# Presolve time: 0.03s
# Presolved: 6481 rows, 876 columns, 28429 nonzeros
# Variable types: 0 continuous, 876 integer (750 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.400000e+02, 566 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  540.00000    0   68          -  540.00000      -     -    0s
#      0     0  540.00000    0  101          -  540.00000      -     -    0s
#      0     0  540.00000    0  100          -  540.00000      -     -    0s
#      0     0  540.00000    0   11          -  540.00000      -     -    0s
# H    0     0                     940.0000000  540.00000  42.6%     -    0s
#      0     0  540.00000    0   22  940.00000  540.00000  42.6%     -    0s
# H    0     0                     850.0000000  540.00000  36.5%     -    0s
# H    0     0                     815.0000000  540.00000  33.7%     -    0s
# H    0     0                     795.0000000  540.00000  32.1%     -    0s
#      0     0  540.00000    0   15  795.00000  540.00000  32.1%     -    0s
#      0     0  540.00000    0   17  795.00000  540.00000  32.1%     -    0s
# H    0     0                     700.0000000  540.00000  22.9%     -    0s
#      0     0  540.00000    0   11  700.00000  540.00000  22.9%     -    0s
#      0     0  540.00000    0   14  700.00000  540.00000  22.9%     -    0s
# H    0     0                     660.0000000  540.00000  18.2%     -    0s
# H    0     0                     615.0000000  540.00000  12.2%     -    0s
#      0     0  540.00000    0   47  615.00000  540.00000  12.2%     -    0s
# H    0     0                     600.0000000  540.00000  10.0%     -    0s
#      0     0  540.00000    0   29  600.00000  540.00000  10.0%     -    0s
#      0     0  540.00000    0   22  600.00000  540.00000  10.0%     -    0s
#      0     0  540.00000    0   18  600.00000  540.00000  10.0%     -    0s
# H    0     0                     595.0000000  540.00000  9.24%     -    0s
#      0     2  540.00000    0   18  595.00000  540.00000  9.24%     -    0s
# H   38    41                     590.0000000  540.00000  8.47%  26.4    1s
# H   77    64                     580.0000000  540.00000  6.90%  22.9    1s
#   2013  1250  570.00000   31    2  580.00000  570.00000  1.72%  16.6    5s
#   4391   862 infeasible   32       580.00000  570.00000  1.72%  49.7   10s
#
# Cutting planes:
#   RLT: 2
#
# Explored 6789 nodes (486024 simplex iterations) in 14.00 seconds (27.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 580 590 595 ... 850
#
# Time limit reached
# Best objective 5.800000000000e+02, best bound 5.700000000000e+02, gap 1.7241%
#
# User-callback calls 17961, time in user-callback 0.02 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 16.csv", 2000, 16)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 16
# Set parameter TimeLimit to value 16
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 9242 rows, 4824 columns and 41665 nonzeros
# Model fingerprint: 0xff5597a9
# Variable types: 0 continuous, 4824 integer (4603 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 81 rows and 3745 columns
# Presolve time: 0.03s
# Presolved: 9161 rows, 1079 columns, 39867 nonzeros
# Variable types: 0 continuous, 1079 integer (937 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 6.000000e+02, 584 iterations, 0.02 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  600.00000    0   56          -  600.00000      -     -    0s
#      0     0  600.00000    0   99          -  600.00000      -     -    0s
#      0     0  600.00000    0  100          -  600.00000      -     -    0s
#      0     0  600.00000    0   30          -  600.00000      -     -    0s
#      0     0  600.00000    0   39          -  600.00000      -     -    0s
# H    0     0                     975.0000000  600.00000  38.5%     -    0s
# H    0     0                     880.0000000  600.00000  31.8%     -    0s
#      0     0  600.00000    0   30  880.00000  600.00000  31.8%     -    0s
# H    0     0                     825.0000000  600.00000  27.3%     -    0s
#      0     0  600.00000    0   19  825.00000  600.00000  27.3%     -    0s
# H    0     0                     785.0000000  600.00000  23.6%     -    0s
# H    0     0                     700.0000000  600.00000  14.3%     -    0s
#      0     0  600.00000    0   25  700.00000  600.00000  14.3%     -    0s
#      0     0  600.00000    0   29  700.00000  600.00000  14.3%     -    1s
#      0     0  600.00000    0   29  700.00000  600.00000  14.3%     -    1s
#      0     0  600.00000    0   35  700.00000  600.00000  14.3%     -    1s
#      0     0  600.00000    0   47  700.00000  600.00000  14.3%     -    1s
# H    0     0                     695.0000000  600.00000  13.7%     -    1s
#      0     0  600.00000    0   47  695.00000  600.00000  13.7%     -    1s
#      0     0  600.00000    0   47  695.00000  600.00000  13.7%     -    1s
#      0     2  600.00000    0   26  695.00000  600.00000  13.7%     -    1s
# H   88    75                     690.0000000  600.00000  13.0%  25.6    1s
# H   91    75                     685.0000000  600.00000  12.4%  24.8    1s
# H   95    75                     680.0000000  600.00000  11.8%  24.4    1s
# H  100    75                     670.0000000  600.00000  10.4%  24.1    1s
# H  141    96                     665.0000000  600.00000  9.77%  19.7    2s
# H  240   155                     640.0000000  600.00000  6.25%  22.0    2s
#   2345  1341  630.00000   44   35  640.00000  630.00000  1.56%  14.4    5s
#   3360  1932  630.00000   34   27  640.00000  630.00000  1.56%  22.4   10s
#   6504  1405  630.00000   39   16  640.00000  630.00000  1.56%  42.0   16s
#
# Cutting planes:
#   Gomory: 1
#   StrongCG: 2
#   Flow cover: 3
#   Zero half: 1
#   RLT: 5
#
# Explored 7114 nodes (354816 simplex iterations) in 16.01 seconds (32.90 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 640 665 670 ... 825
#
# Time limit reached
# Best objective 6.400000000000e+02, best bound 6.300000000000e+02, gap 1.5625%
#
# User-callback calls 19942, time in user-callback 0.01 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 18.csv", 2000, 18)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 18
# Set parameter TimeLimit to value 18
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 14289 rows, 7218 columns and 63612 nonzeros
# Model fingerprint: 0x5e049544
# Variable types: 0 continuous, 7218 integer (6964 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 93 rows and 5819 columns
# Presolve time: 0.04s
# Presolved: 14196 rows, 1399 columns, 61120 nonzeros
# Variable types: 0 continuous, 1399 integer (1233 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 7.200000e+02, 770 iterations, 0.04 seconds (0.10 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  720.00000    0   59          -  720.00000      -     -    0s
#      0     0  720.00000    0  138          -  720.00000      -     -    0s
#      0     0  720.00000    0  140          -  720.00000      -     -    0s
#      0     0  720.00000    0   39          -  720.00000      -     -    0s
#      0     0  720.00000    0   30          -  720.00000      -     -    0s
# H    0     0                    1335.0000000  720.00000  46.1%     -    1s
# H    0     0                    1295.0000000  720.00000  44.4%     -    1s
#      0     0  720.00000    0   35 1295.00000  720.00000  44.4%     -    1s
# H    0     0                    1060.0000000  720.00000  32.1%     -    1s
# H    0     0                    1030.0000000  720.00000  30.1%     -    1s
#      0     0  720.00000    0   17 1030.00000  720.00000  30.1%     -    1s
# H    0     0                     885.0000000  720.00000  18.6%     -    1s
# H    0     0                     880.0000000  720.00000  18.2%     -    1s
#      0     0  720.00000    0   24  880.00000  720.00000  18.2%     -    1s
# H    0     0                     850.0000000  720.00000  15.3%     -    1s
# H    0     0                     820.0000000  720.00000  12.2%     -    1s
#      0     0  720.00000    0   19  820.00000  720.00000  12.2%     -    1s
#      0     0  720.00000    0   17  820.00000  720.00000  12.2%     -    1s
# H    0     0                     800.0000000  720.00000  10.0%     -    1s
#      0     0  720.00000    0   15  800.00000  720.00000  10.0%     -    1s
# H    0     0                     795.0000000  720.00000  9.43%     -    2s
# H    0     0                     790.0000000  720.00000  8.86%     -    2s
#      0     0  720.00000    0   17  790.00000  720.00000  8.86%     -    2s
#      0     0  720.00000    0   19  790.00000  720.00000  8.86%     -    2s
#      0     0  720.00000    0   23  790.00000  720.00000  8.86%     -    2s
# H    0     0                     770.0000000  720.00000  6.49%     -    2s
#      0     0  720.00000    0   17  770.00000  720.00000  6.49%     -    2s
#      0     2  720.00000    0   14  770.00000  720.00000  6.49%     -    2s
# H   87    66                     760.0000000  720.00000  5.26%  40.1    3s
#    459   349  750.00000   37   83  760.00000  720.00000  5.26%  21.4    6s
#   1814  1244  750.00000   50   35  760.00000  750.00000  1.32%  17.2   10s
#   1965  1412  750.00000   23   23  760.00000  750.00000  1.32%   9.3   15s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 3
#   Implied bound: 1
#   Clique: 2
#   StrongCG: 1
#   Flow cover: 2
#   GUB cover: 1
#
# Explored 3621 nodes (107028 simplex iterations) in 18.01 seconds (38.37 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 760 770 790 ... 1030
#
# Time limit reached
# Best objective 7.600000000000e+02, best bound 7.500000000000e+02, gap 1.3158%
#
# User-callback calls 12517, time in user-callback 0.01 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 20.csv", 2000, 20)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 16584 rows, 8496 columns and 73941 nonzeros
# Model fingerprint: 0x7a0d8bb9
# Variable types: 0 continuous, 8496 integer (8224 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 97 rows and 6887 columns
# Presolve time: 0.06s
# Presolved: 16487 rows, 1609 columns, 70377 nonzeros
# Variable types: 0 continuous, 1609 integer (1428 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 7.200000e+02, 775 iterations, 0.04 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  720.00000    0   68          -  720.00000      -     -    0s
#      0     0  720.00000    0  202          -  720.00000      -     -    0s
#      0     0  720.00000    0  195          -  720.00000      -     -    0s
# H    0     0                    1520.0000000  720.00000  52.6%     -    0s
# H    0     0                    1460.0000000  720.00000  50.7%     -    0s
# H    0     0                    1280.0000000  720.00000  43.8%     -    0s
# H    0     0                    1240.0000000  720.00000  41.9%     -    0s
#      0     0  720.00000    0   76 1240.00000  720.00000  41.9%     -    0s
# H    0     0                    1230.0000000  720.00000  41.5%     -    1s
# H    0     0                    1130.0000000  720.00000  36.3%     -    1s
# H    0     0                    1020.0000000  720.00000  29.4%     -    1s
#      0     0  720.00000    0   40 1020.00000  720.00000  29.4%     -    1s
# H    0     0                     995.0000000  720.00000  27.6%     -    1s
# H    0     0                     975.0000000  720.00000  26.2%     -    1s
# H    0     0                     955.0000000  720.00000  24.6%     -    1s
# H    0     0                     885.0000000  720.00000  18.6%     -    1s
# H    0     0                     880.0000000  720.00000  18.2%     -    1s
#      0     0  720.00000    0   30  880.00000  720.00000  18.2%     -    1s
# H    0     0                     870.0000000  720.00000  17.2%     -    1s
#      0     0  720.00000    0   34  870.00000  720.00000  17.2%     -    1s
#      0     0  720.00000    0   32  870.00000  720.00000  17.2%     -    2s
#      0     0  720.00000    0   59  870.00000  720.00000  17.2%     -    2s
# H    0     0                     840.0000000  720.00000  14.3%     -    2s
#      0     0  720.00000    0   36  840.00000  720.00000  14.3%     -    2s
#      0     0  720.00000    0   36  840.00000  720.00000  14.3%     -    2s
# H    0     0                     800.0000000  720.00000  10.0%     -    2s
#      0     0  720.00000    0   36  800.00000  720.00000  10.0%     -    2s
#      0     0  720.00000    0   37  800.00000  720.00000  10.0%     -    2s
#      0     0  720.00000    0   31  800.00000  720.00000  10.0%     -    3s
#      0     2  720.00000    0   29  800.00000  720.00000  10.0%     -    3s
# H   87    73                     790.0000000  720.00000  8.86%  39.7    4s
#    144   124  720.00000   14   42  790.00000  720.00000  8.86%  63.8    5s
# H  688   657                     780.0000000  720.00000  7.69%  37.5    9s
# H  961   657                     760.0000000  720.00000  5.26%  32.5    9s
#    981  1169     cutoff   54       760.00000  720.00000  5.26%  33.2   11s
#   3575  1977  750.00000   17   72  760.00000  750.00000  1.32%  30.4   15s
#   3665  2041  750.00000   22   18  760.00000  750.00000  1.32%   4.8   20s
#
# Cutting planes:
#   Cover: 3
#   Projected implied bound: 2
#   Clique: 3
#   Zero half: 1
#   RLT: 6
#
# Explored 3678 nodes (137600 simplex iterations) in 20.01 seconds (47.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 760 780 790 ... 975
#
# Time limit reached
# Best objective 7.600000000000e+02, best bound 7.500000000000e+02, gap 1.3158%
#
# User-callback calls 14405, time in user-callback 0.00 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 22.csv", 2000, 22)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 22
# Set parameter TimeLimit to value 22
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 23846 rows, 11902 columns and 105179 nonzeros
# Model fingerprint: 0xf1e23db9
# Variable types: 0 continuous, 11902 integer (11597 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 110 rows and 9913 columns
# Presolve time: 0.08s
# Presolved: 23736 rows, 1989 columns, 100573 nonzeros
# Variable types: 0 continuous, 1989 integer (1784 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 8.400000e+02, 1049 iterations, 0.07 seconds (0.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  840.00000    0   61          -  840.00000      -     -    0s
# H    0     0                    1580.0000000  840.00000  46.8%     -    0s
# H    0     0                    1340.0000000  840.00000  37.3%     -    0s
#      0     0  840.00000    0  104 1340.00000  840.00000  37.3%     -    0s
# H    0     0                    1220.0000000  840.00000  31.1%     -    1s
# H    0     0                    1190.0000000  840.00000  29.4%     -    1s
# H    0     0                    1145.0000000  840.00000  26.6%     -    1s
# H    0     0                    1005.0000000  840.00000  16.4%     -    1s
# H    0     0                     955.0000000  840.00000  12.0%     -    1s
#      0     0  840.00000    0   38  955.00000  840.00000  12.0%     -    1s
# H    0     0                     930.0000000  840.00000  9.68%     -    2s
# H    0     0                     910.0000000  840.00000  7.69%     -    2s
#      0     0  840.00000    0   34  910.00000  840.00000  7.69%     -    2s
#      0     0  840.00000    0   57  910.00000  840.00000  7.69%     -    2s
#      0     0  840.00000    0   64  910.00000  840.00000  7.69%     -    2s
#      0     0  840.00000    0   48  910.00000  840.00000  7.69%     -    3s
#      0     0  840.00000    0   50  910.00000  840.00000  7.69%     -    3s
# H    0     0                     880.0000000  840.00000  4.55%     -    3s
#      0     0  840.00000    0   32  880.00000  840.00000  4.55%     -    3s
#      0     0  840.00000    0   41  880.00000  840.00000  4.55%     -    4s
#      0     0  840.00000    0   34  880.00000  840.00000  4.55%     -    5s
#      0     0  840.00000    0   34  880.00000  840.00000  4.55%     -    5s
#      0     0  840.00000    0   49  880.00000  840.00000  4.55%     -    5s
#      0     0  840.00000    0   49  880.00000  840.00000  4.55%     -    6s
#      0     2  840.00000    0   49  880.00000  840.00000  4.55%     -    6s
#    250   121  870.00000   24  118  880.00000  840.00000  4.55%  21.8   11s
#    646   395  870.00000   45  145  880.00000  840.00000  4.55%  20.2   16s
#   1178   730 infeasible   15       880.00000  870.00000  1.14%  25.3   20s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 141
#   Implied bound: 3
#   Clique: 6
#   MIR: 14
#   StrongCG: 2
#   RLT: 3
#   Relax-and-lift: 4
#
# Explored 3909 nodes (112295 simplex iterations) in 22.04 seconds (61.83 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 880 910 930 ... 1580
#
# Time limit reached
# Best objective 8.800000000000e+02, best bound 8.700000000000e+02, gap 1.1364%
#
# User-callback calls 13885, time in user-callback 0.01 sec

# %%
my_model, nk, MM, II, x_result, h_result, s_result, s0_result, TX_result = build_optimization_model("level3/JSSPlvl3 - 24.csv", 2000, 24)
gantt_chart_with_job_legends = plot_gantt_chart_with_job_legends(h_result, TX_result, x_result, nk, MM, II)
display(gantt_chart_with_job_legends)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-22
# Set parameter TimeLimit to value 24
# Set parameter TimeLimit to value 24
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[arm])
#
# CPU model: Apple M2 Max
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 30414 rows, 15359 columns and 133509 nonzeros
# Model fingerprint: 0x21cacf29
# Variable types: 0 continuous, 15359 integer (15027 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
# Presolve removed 118 rows and 13019 columns
# Presolve time: 0.09s
# Presolved: 30296 rows, 2340 columns, 127964 nonzeros
# Variable types: 0 continuous, 2340 integer (2116 binary)
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 9.000000e+02, 1230 iterations, 0.10 seconds (0.32 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  900.00000    0   68          -  900.00000      -     -    0s
#      0     0  900.00000    0  115          -  900.00000      -     -    1s
#      0     0  900.00000    0   67          -  900.00000      -     -    2s
# H    0     0                    1825.0000000  900.00000  50.7%     -    2s
#      0     0  900.00000    0   61 1825.00000  900.00000  50.7%     -    2s
# H    0     0                    1365.0000000  900.00000  34.1%     -    2s
#      0     0  900.00000    0   61 1365.00000  900.00000  34.1%     -    2s
#      0     0  900.00000    0   44 1365.00000  900.00000  34.1%     -    3s
#      0     0  900.00000    0   43 1365.00000  900.00000  34.1%     -    3s
# H    0     0                    1245.0000000  900.00000  27.7%     -    3s
# H    0     0                    1100.0000000  900.00000  18.2%     -    3s
#      0     0  900.00000    0   45 1100.00000  900.00000  18.2%     -    3s
# H    0     0                    1095.0000000  900.00000  17.8%     -    4s
# H    0     0                    1035.0000000  900.00000  13.0%     -    4s
#      0     0  900.00000    0   42 1035.00000  900.00000  13.0%     -    4s
# H    0     0                    1030.0000000  900.00000  12.6%     -    4s
# H    0     0                    1005.0000000  900.00000  10.4%     -    4s
#      0     0  900.00000    0   46 1005.00000  900.00000  10.4%     -    4s
# H    0     0                     980.0000000  900.00000  8.16%     -    5s
# H    0     0                     950.0000000  900.00000  5.26%     -    5s
# H    0     0                     940.0000000  900.00000  4.26%     -    5s
#      0     0  900.00000    0   71  940.00000  900.00000  4.26%     -    5s
#      0     0  900.00000    0  147  940.00000  900.00000  4.26%     -    6s
#      0     0  900.00000    0  112  940.00000  900.00000  4.26%     -    7s
#      0     0  900.00000    0   74  940.00000  900.00000  4.26%     -    7s
#      0     2  900.00000    0   58  940.00000  900.00000  4.26%     -    8s
#     87    86  900.00000    8   77  940.00000  900.00000  4.26%  52.5   10s
#    457   457  900.00000   23   94  940.00000  900.00000  4.26%  53.8   17s
#    618   532  900.00000   36   65  940.00000  900.00000  4.26%  51.9   21s
#
# Cutting planes:
#   Cover: 24
#   Implied bound: 3
#   Clique: 1
#   MIR: 8
#   RLT: 4
#   Relax-and-lift: 3
#
# Explored 1490 nodes (79352 simplex iterations) in 24.03 seconds (65.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 940 950 980 ... 1365
#
# Time limit reached
# Best objective 9.400000000000e+02, best bound 9.000000000000e+02, gap 4.2553%
#
# User-callback calls 11030, time in user-callback 0.01 sec
